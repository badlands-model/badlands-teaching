# %% [markdown]
# # Install badlands
#
# > Run the following `code cell` to install the *latest* version of badlands on your `binder instance`.

# %%
# !pip install --no-deps badlands; pip install badlands

# %% [markdown]
# ## Go to the [Stratigraphy](./stratigraphy/) exercises
#
# ## Go to the [Geomorphology](./geomorphology/) exercises
